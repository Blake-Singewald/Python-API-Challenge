# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import pandas as pd
import hvplot.pandas
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0          geraldton -28.7667  114.6000     88.21        22
# 1        1           waitangi -43.9535 -176.5597     64.81        93
# 2        2         avanigadda  16.0215   80.9181     71.60        92
# 3        3  wailua homesteads  22.0669 -159.3780     77.43        75
# 4        4          adamstown -25.0660 -130.1015     76.69        88
#
#    Cloudiness  Wind Speed Country        Date
# 0           0       13.80      AU  1706826649
# 1          99        1.01      NZ  1706826839
# 2          92        3.94      IN  1706826840
# 3          20        6.91      US  1706826840
# 4          42       20.20      PN  1706826840

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
humidity = city_data_df["Humidity"].astype(int)

# Configure the map plot
humidity_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    color="City",
    alpha=.75
)

# Display the map
humidity_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_data_df

#A max temperature lower than 27 degrees but higher than 21
city_data_df = city_data_df.loc[(city_data_df["Max Temp"] < 80) & (city_data_df["Max Temp"] > 40)]

#Wind speed less than 10 mph
city_data_df = city_data_df.loc[(city_data_df["Wind Speed"] < 10)]

#Overhead cloudiness of less equal 40%
city_data_df = city_data_df.loc[(city_data_df["Cloudiness"] <= 40)]

#Humidity less equal 80%
city_data_df = city_data_df.loc[(city_data_df["Humidity"] <=  80)]
# Drop any rows with null values

city_data_df = city_data_df.dropna()

# Display sample data
city_data_df
# Out:
#      City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 3          3      wailua homesteads  22.0669 -159.3780     77.43        75
# 27        27                 at taj  24.2049   23.2857     43.75        52
# 32        32                  ha'il  27.5219   41.6907     44.62        57
# 42        42          fort mcmurray  56.7268 -111.3810     45.99        61
# 45        45               ban phai  16.0600  102.7310     76.10        59
# 71        71                machico  32.7000  -16.7667     67.12        71
# 123      123                kyaukse  21.6000   96.1333     62.29        43
# 134      134          alice springs -23.7000  133.8833     72.95        21
# 136      136                   tura  25.5198   90.2201     56.35        75
# 146      146             greenville  35.6127  -77.3663     53.64        61
# 148      148                 kapa'a  22.0752 -159.3190     78.78        74
# 149      149          jaisinghnagar  23.7000   81.3833     58.37        52
# 152      152                   chui -33.6971  -53.4616     71.67        80
# 162      162                ballina -28.8667  153.5667     79.79        63
# 163      163                sharjah  25.3573   55.4033     75.18        73
# 164      164               kalundri  18.9833   73.1333     75.20        73
# 165      165                  aswan  24.0934   32.9070     51.10        43
# 175      175          jumri tilaiya  24.4333   85.5167     56.08        66
# 199      199             slave lake  55.2834 -114.7690     44.58        57
# 215      215  el abiodh sidi cheikh  32.8930    0.5484     48.13        42
# 216      216                zuwarah  32.9312   12.0820     55.65        60
# 239      239          morehead city  34.7229  -76.7260     53.65        74
# 249      249               el casar  38.5309   -5.9251     50.99        70
# 265      265           luang namtha  20.9497  101.4011     54.82        77
# 271      271                 jerada  34.3100   -2.1600     46.92        76
# 282      282                  lihue  21.9789 -159.3672     78.04        73
# 284      284            tamanrasset  22.7850    5.5228     48.11        18
# 292      292                badiyah  22.4500   58.8000     69.10        76
# 299      299                 daphne  30.6035  -87.9036     61.36        62
# 307      307                 helena  46.5927 -112.0361     57.16        52
# 310      310   phayakkhaphum phisai  15.5163  103.1937     77.56        56
# 312      312       chesapeake beach  38.6862  -76.5347     52.75        73
# 331      331                xai-xai -25.0519   33.6442     74.88        78
# 340      340                  cooma -36.2333  149.1333     70.68        42
# 350      350             the bottom  17.6259  -63.2492     77.13        73
# 356      356              tazacorte  28.6290  -17.9293     71.15        35
# 365      365             fort bragg  35.1390  -79.0060     57.34        54
# 368      368            palia kalan  28.4500   80.5833     50.59        80
# 377      377            taylorville  39.5489  -89.2945     58.26        76
# 379      379                 gebeit  21.0667   36.3167     49.19        27
# 383      383               holdrege  40.4403  -99.3698     53.51        67
# 390      390                 lupane -18.9315   27.8070     64.22        80
# 422      422         miguel ahumada  30.6167 -106.5167     73.38        21
# 428      428                 ruteng  -8.6136  120.4721     65.21        80
# 433      433               skiathos  39.1623   23.4909     45.97        47
# 434      434              polygyros  40.3744   23.4383     40.60        44
# 442      442            bahia honda  22.9036  -83.1592     68.13        70
# 475      475          haiku-pauwela  20.9219 -156.3051     78.82        70
# 480      480            bodden town  19.2833  -81.2500     75.20        68
# 515      515              ain sefra  32.7500   -0.5833     45.00        45
# 528      528                 bentiu   9.2333   29.8333     74.68        16
# 530      530                 loikaw  19.6742   97.2094     52.11        37
# 537      537              kyaikkami  16.0800   97.5675     75.88        77
# 543      543       kill devil hills  36.0307  -75.6760     44.98        73
# 567      567                   ovar  40.8586   -8.6251     59.02        69
# 569      569                dhanwar  24.4167   85.9833     57.72        65
#
#      Cloudiness  Wind Speed Country        Date
# 3            20        6.91      US  1706826840
# 27            0        7.58      LY  1706826845
# 32            0        9.22      SA  1706826846
# 42            0        5.75      CA  1706826641
# 45           17        0.27      TH  1706826849
# 71           20        5.75      PT  1706826854
# 123           1        4.23      MM  1706826865
# 134           1        4.61      AU  1706826867
# 136           3        2.73      IN  1706826868
# 146           0        3.44      US  1706826610
# 148          20        6.91      US  1706826870
# 149          32        4.21      IN  1706826871
# 152           0        8.39      UY  1706826871
# 162           8        4.85      AU  1706826873
# 163           0        5.75      AE  1706826873
# 164           0        4.09      IN  1706826874
# 165           0        4.61      EG  1706826874
# 175           5        4.14      IN  1706826876
# 199           0        5.75      CA  1706826880
# 215           0        3.15      DZ  1706826883
# 216           5        5.14      LY  1706826884
# 239           0        8.05      US  1706826888
# 249          21        2.86      ES  1706826890
# 265           0        1.03      LA  1706826892
# 271           2        2.95      MA  1706826894
# 282          20        6.91      US  1706826737
# 284           0        4.61      DZ  1706826896
# 292          11        2.01      OM  1706826897
# 299           0        6.91      US  1706826899
# 307           0        0.00      US  1706826900
# 310           2        2.39      TH  1706826901
# 312          40        8.01      US  1706826901
# 331           3        9.08      MZ  1706826906
# 340           0        3.91      AU  1706826908
# 350           1        7.87      BQ  1706826910
# 356           0        8.99      ES  1706826911
# 365           0        9.22      US  1706826913
# 368           0        5.61      IN  1706826914
# 377           0        6.91      US  1706826737
# 379           1        6.33      SD  1706826917
# 383           0        5.75      US  1706826918
# 390          35        5.55      ZW  1706826919
# 422           1        6.51      MX  1706826926
# 428          39        0.85      ID  1706826927
# 433           2        6.11      GR  1706826856
# 434           6        3.85      GR  1706826928
# 442          33        7.63      CU  1706826930
# 475          40        8.05      US  1706826937
# 480          20        9.22      KY  1706826938
# 515           1        3.74      DZ  1706826945
# 528           6        8.93      SS  1706826948
# 530           0        3.31      MM  1706826948
# 537           0        4.16      MM  1706826949
# 543           0        3.44      US  1706826950
# 567          14        4.43      PT  1706826955
# 569           3        5.30      IN  1706826955

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df.copy(deep = True)

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#      City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 3          3      wailua homesteads  22.0669 -159.3780     77.43        75
# 27        27                 at taj  24.2049   23.2857     43.75        52
# 32        32                  ha'il  27.5219   41.6907     44.62        57
# 42        42          fort mcmurray  56.7268 -111.3810     45.99        61
# 45        45               ban phai  16.0600  102.7310     76.10        59
# 71        71                machico  32.7000  -16.7667     67.12        71
# 123      123                kyaukse  21.6000   96.1333     62.29        43
# 134      134          alice springs -23.7000  133.8833     72.95        21
# 136      136                   tura  25.5198   90.2201     56.35        75
# 146      146             greenville  35.6127  -77.3663     53.64        61
# 148      148                 kapa'a  22.0752 -159.3190     78.78        74
# 149      149          jaisinghnagar  23.7000   81.3833     58.37        52
# 152      152                   chui -33.6971  -53.4616     71.67        80
# 162      162                ballina -28.8667  153.5667     79.79        63
# 163      163                sharjah  25.3573   55.4033     75.18        73
# 164      164               kalundri  18.9833   73.1333     75.20        73
# 165      165                  aswan  24.0934   32.9070     51.10        43
# 175      175          jumri tilaiya  24.4333   85.5167     56.08        66
# 199      199             slave lake  55.2834 -114.7690     44.58        57
# 215      215  el abiodh sidi cheikh  32.8930    0.5484     48.13        42
# 216      216                zuwarah  32.9312   12.0820     55.65        60
# 239      239          morehead city  34.7229  -76.7260     53.65        74
# 249      249               el casar  38.5309   -5.9251     50.99        70
# 265      265           luang namtha  20.9497  101.4011     54.82        77
# 271      271                 jerada  34.3100   -2.1600     46.92        76
# 282      282                  lihue  21.9789 -159.3672     78.04        73
# 284      284            tamanrasset  22.7850    5.5228     48.11        18
# 292      292                badiyah  22.4500   58.8000     69.10        76
# 299      299                 daphne  30.6035  -87.9036     61.36        62
# 307      307                 helena  46.5927 -112.0361     57.16        52
# 310      310   phayakkhaphum phisai  15.5163  103.1937     77.56        56
# 312      312       chesapeake beach  38.6862  -76.5347     52.75        73
# 331      331                xai-xai -25.0519   33.6442     74.88        78
# 340      340                  cooma -36.2333  149.1333     70.68        42
# 350      350             the bottom  17.6259  -63.2492     77.13        73
# 356      356              tazacorte  28.6290  -17.9293     71.15        35
# 365      365             fort bragg  35.1390  -79.0060     57.34        54
# 368      368            palia kalan  28.4500   80.5833     50.59        80
# 377      377            taylorville  39.5489  -89.2945     58.26        76
# 379      379                 gebeit  21.0667   36.3167     49.19        27
# 383      383               holdrege  40.4403  -99.3698     53.51        67
# 390      390                 lupane -18.9315   27.8070     64.22        80
# 422      422         miguel ahumada  30.6167 -106.5167     73.38        21
# 428      428                 ruteng  -8.6136  120.4721     65.21        80
# 433      433               skiathos  39.1623   23.4909     45.97        47
# 434      434              polygyros  40.3744   23.4383     40.60        44
# 442      442            bahia honda  22.9036  -83.1592     68.13        70
# 475      475          haiku-pauwela  20.9219 -156.3051     78.82        70
# 480      480            bodden town  19.2833  -81.2500     75.20        68
# 515      515              ain sefra  32.7500   -0.5833     45.00        45
# 528      528                 bentiu   9.2333   29.8333     74.68        16
# 530      530                 loikaw  19.6742   97.2094     52.11        37
# 537      537              kyaikkami  16.0800   97.5675     75.88        77
# 543      543       kill devil hills  36.0307  -75.6760     44.98        73
# 567      567                   ovar  40.8586   -8.6251     59.02        69
# 569      569                dhanwar  24.4167   85.9833     57.72        65
#
#      Cloudiness  Wind Speed Country        Date Hotel Name
# 3            20        6.91      US  1706826840
# 27            0        7.58      LY  1706826845
# 32            0        9.22      SA  1706826846
# 42            0        5.75      CA  1706826641
# 45           17        0.27      TH  1706826849
# 71           20        5.75      PT  1706826854
# 123           1        4.23      MM  1706826865
# 134           1        4.61      AU  1706826867
# 136           3        2.73      IN  1706826868
# 146           0        3.44      US  1706826610
# 148          20        6.91      US  1706826870
# 149          32        4.21      IN  1706826871
# 152           0        8.39      UY  1706826871
# 162           8        4.85      AU  1706826873
# 163           0        5.75      AE  1706826873
# 164           0        4.09      IN  1706826874
# 165           0        4.61      EG  1706826874
# 175           5        4.14      IN  1706826876
# 199           0        5.75      CA  1706826880
# 215           0        3.15      DZ  1706826883
# 216           5        5.14      LY  1706826884
# 239           0        8.05      US  1706826888
# 249          21        2.86      ES  1706826890
# 265           0        1.03      LA  1706826892
# 271           2        2.95      MA  1706826894
# 282          20        6.91      US  1706826737
# 284           0        4.61      DZ  1706826896
# 292          11        2.01      OM  1706826897
# 299           0        6.91      US  1706826899
# 307           0        0.00      US  1706826900
# 310           2        2.39      TH  1706826901
# 312          40        8.01      US  1706826901
# 331           3        9.08      MZ  1706826906
# 340           0        3.91      AU  1706826908
# 350           1        7.87      BQ  1706826910
# 356           0        8.99      ES  1706826911
# 365           0        9.22      US  1706826913
# 368           0        5.61      IN  1706826914
# 377           0        6.91      US  1706826737
# 379           1        6.33      SD  1706826917
# 383           0        5.75      US  1706826918
# 390          35        5.55      ZW  1706826919
# 422           1        6.51      MX  1706826926
# 428          39        0.85      ID  1706826927
# 433           2        6.11      GR  1706826856
# 434           6        3.85      GR  1706826928
# 442          33        7.63      CU  1706826930
# 475          40        8.05      US  1706826937
# 480          20        9.22      KY  1706826938
# 515           1        3.74      DZ  1706826945
# 528           6        8.93      SS  1706826948
# 530           0        3.31      MM  1706826948
# 537           0        4.16      MM  1706826949
# 543           0        3.44      US  1706826950
# 567          14        4.43      PT  1706826955
# 569           3        5.30      IN  1706826955

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# at taj - nearest hotel: No hotel found
# ha'il - nearest hotel: فندق كلاسيك
# fort mcmurray - nearest hotel: Nomad Hotel and Suites
# ban phai - nearest hotel: No hotel found
# machico - nearest hotel: Residence Inn
# kyaukse - nearest hotel: San Palace Hotel
# alice springs - nearest hotel: Aurora Alice Springs
# tura - nearest hotel: No hotel found
# greenville - nearest hotel: Quality Inn
# kapa'a - nearest hotel: Pono Kai Resort
# jaisinghnagar - nearest hotel: No hotel found
# chui - nearest hotel: Alerces
# ballina - nearest hotel: Ballina Beach Resort
# sharjah - nearest hotel: shakeel bhai room
# kalundri - nearest hotel: Hotel Geetenjali
# aswan - nearest hotel: Yaseen hotel
# jumri tilaiya - nearest hotel: No hotel found
# slave lake - nearest hotel: Northwest Inn
# el abiodh sidi cheikh - nearest hotel: No hotel found
# zuwarah - nearest hotel: فندق الدلفين
# morehead city - nearest hotel: Bask Hotel Big Rock Landing, Trademark Collection by Wyndham
# el casar - nearest hotel: No hotel found
# luang namtha - nearest hotel: Khounxaisavanh Guesthouse
# jerada - nearest hotel: No hotel found
# lihue - nearest hotel: Kauai Palms
# tamanrasset - nearest hotel: فندق الأمان
# badiyah - nearest hotel: Al Areen Hotel Apartments
# daphne - nearest hotel: Hampton Inn Mobile-East Bay/Daphne
# helena - nearest hotel: DoubleTree
# phayakkhaphum phisai - nearest hotel: Sapvilai Hotel
# chesapeake beach - nearest hotel: Chesapeake Beach Resort and Spa
# xai-xai - nearest hotel: No hotel found
# cooma - nearest hotel: Royal Hotel
# the bottom - nearest hotel: Queen's Garden Resort
# tazacorte - nearest hotel: App Leyma
# fort bragg - nearest hotel: Airborne Inn Lodging
# palia kalan - nearest hotel: No hotel found
# taylorville - nearest hotel: No hotel found
# gebeit - nearest hotel: No hotel found
# holdrege - nearest hotel: Hotel Dale
# lupane - nearest hotel: No hotel found
# miguel ahumada - nearest hotel: Hotel Mexico
# ruteng - nearest hotel: No hotel found
# skiathos - nearest hotel: Pension pineapple
# polygyros - nearest hotel: Glavas Hotel
# bahia honda - nearest hotel: No hotel found
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# bodden town - nearest hotel: Turtle Nest Inn
# ain sefra - nearest hotel: فندق مكثر
# bentiu - nearest hotel: Peace Hotel
# loikaw - nearest hotel: Nawaday Hotel
# kyaikkami - nearest hotel: ရှုခင်းသာ
# kill devil hills - nearest hotel: Mariner Days Inn & Suites
# ovar - nearest hotel: Aqua Hotel
# dhanwar - nearest hotel: No hotel found
#      City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 3          3      wailua homesteads  22.0669 -159.3780     77.43        75
# 27        27                 at taj  24.2049   23.2857     43.75        52
# 32        32                  ha'il  27.5219   41.6907     44.62        57
# 42        42          fort mcmurray  56.7268 -111.3810     45.99        61
# 45        45               ban phai  16.0600  102.7310     76.10        59
# 71        71                machico  32.7000  -16.7667     67.12        71
# 123      123                kyaukse  21.6000   96.1333     62.29        43
# 134      134          alice springs -23.7000  133.8833     72.95        21
# 136      136                   tura  25.5198   90.2201     56.35        75
# 146      146             greenville  35.6127  -77.3663     53.64        61
# 148      148                 kapa'a  22.0752 -159.3190     78.78        74
# 149      149          jaisinghnagar  23.7000   81.3833     58.37        52
# 152      152                   chui -33.6971  -53.4616     71.67        80
# 162      162                ballina -28.8667  153.5667     79.79        63
# 163      163                sharjah  25.3573   55.4033     75.18        73
# 164      164               kalundri  18.9833   73.1333     75.20        73
# 165      165                  aswan  24.0934   32.9070     51.10        43
# 175      175          jumri tilaiya  24.4333   85.5167     56.08        66
# 199      199             slave lake  55.2834 -114.7690     44.58        57
# 215      215  el abiodh sidi cheikh  32.8930    0.5484     48.13        42
# 216      216                zuwarah  32.9312   12.0820     55.65        60
# 239      239          morehead city  34.7229  -76.7260     53.65        74
# 249      249               el casar  38.5309   -5.9251     50.99        70
# 265      265           luang namtha  20.9497  101.4011     54.82        77
# 271      271                 jerada  34.3100   -2.1600     46.92        76
# 282      282                  lihue  21.9789 -159.3672     78.04        73
# 284      284            tamanrasset  22.7850    5.5228     48.11        18
# 292      292                badiyah  22.4500   58.8000     69.10        76
# 299      299                 daphne  30.6035  -87.9036     61.36        62
# 307      307                 helena  46.5927 -112.0361     57.16        52
# 310      310   phayakkhaphum phisai  15.5163  103.1937     77.56        56
# 312      312       chesapeake beach  38.6862  -76.5347     52.75        73
# 331      331                xai-xai -25.0519   33.6442     74.88        78
# 340      340                  cooma -36.2333  149.1333     70.68        42
# 350      350             the bottom  17.6259  -63.2492     77.13        73
# 356      356              tazacorte  28.6290  -17.9293     71.15        35
# 365      365             fort bragg  35.1390  -79.0060     57.34        54
# 368      368            palia kalan  28.4500   80.5833     50.59        80
# 377      377            taylorville  39.5489  -89.2945     58.26        76
# 379      379                 gebeit  21.0667   36.3167     49.19        27
# 383      383               holdrege  40.4403  -99.3698     53.51        67
# 390      390                 lupane -18.9315   27.8070     64.22        80
# 422      422         miguel ahumada  30.6167 -106.5167     73.38        21
# 428      428                 ruteng  -8.6136  120.4721     65.21        80
# 433      433               skiathos  39.1623   23.4909     45.97        47
# 434      434              polygyros  40.3744   23.4383     40.60        44
# 442      442            bahia honda  22.9036  -83.1592     68.13        70
# 475      475          haiku-pauwela  20.9219 -156.3051     78.82        70
# 480      480            bodden town  19.2833  -81.2500     75.20        68
# 515      515              ain sefra  32.7500   -0.5833     45.00        45
# 528      528                 bentiu   9.2333   29.8333     74.68        16
# 530      530                 loikaw  19.6742   97.2094     52.11        37
# 537      537              kyaikkami  16.0800   97.5675     75.88        77
# 543      543       kill devil hills  36.0307  -75.6760     44.98        73
# 567      567                   ovar  40.8586   -8.6251     59.02        69
# 569      569                dhanwar  24.4167   85.9833     57.72        65
#
#      Cloudiness  Wind Speed Country        Date  \
# 3            20        6.91      US  1706826840
# 27            0        7.58      LY  1706826845
# 32            0        9.22      SA  1706826846
# 42            0        5.75      CA  1706826641
# 45           17        0.27      TH  1706826849
# 71           20        5.75      PT  1706826854
# 123           1        4.23      MM  1706826865
# 134           1        4.61      AU  1706826867
# 136           3        2.73      IN  1706826868
# 146           0        3.44      US  1706826610
# 148          20        6.91      US  1706826870
# 149          32        4.21      IN  1706826871
# 152           0        8.39      UY  1706826871
# 162           8        4.85      AU  1706826873
# 163           0        5.75      AE  1706826873
# 164           0        4.09      IN  1706826874
# 165           0        4.61      EG  1706826874
# 175           5        4.14      IN  1706826876
# 199           0        5.75      CA  1706826880
# 215           0        3.15      DZ  1706826883
# 216           5        5.14      LY  1706826884
# 239           0        8.05      US  1706826888
# 249          21        2.86      ES  1706826890
# 265           0        1.03      LA  1706826892
# 271           2        2.95      MA  1706826894
# 282          20        6.91      US  1706826737
# 284           0        4.61      DZ  1706826896
# 292          11        2.01      OM  1706826897
# 299           0        6.91      US  1706826899
# 307           0        0.00      US  1706826900
# 310           2        2.39      TH  1706826901
# 312          40        8.01      US  1706826901
# 331           3        9.08      MZ  1706826906
# 340           0        3.91      AU  1706826908
# 350           1        7.87      BQ  1706826910
# 356           0        8.99      ES  1706826911
# 365           0        9.22      US  1706826913
# 368           0        5.61      IN  1706826914
# 377           0        6.91      US  1706826737
# 379           1        6.33      SD  1706826917
# 383           0        5.75      US  1706826918
# 390          35        5.55      ZW  1706826919
# 422           1        6.51      MX  1706826926
# 428          39        0.85      ID  1706826927
# 433           2        6.11      GR  1706826856
# 434           6        3.85      GR  1706826928
# 442          33        7.63      CU  1706826930
# 475          40        8.05      US  1706826937
# 480          20        9.22      KY  1706826938
# 515           1        3.74      DZ  1706826945
# 528           6        8.93      SS  1706826948
# 530           0        3.31      MM  1706826948
# 537           0        4.16      MM  1706826949
# 543           0        3.44      US  1706826950
# 567          14        4.43      PT  1706826955
# 569           3        5.30      IN  1706826955
#
#                                             Hotel Name
# 3                   Hilton Garden Inn Kauai Wailua Bay
# 27                                      No hotel found
# 32                                         فندق كلاسيك
# 42                              Nomad Hotel and Suites
# 45                                      No hotel found
# 71                                       Residence Inn
# 123                                   San Palace Hotel
# 134                               Aurora Alice Springs
# 136                                     No hotel found
# 146                                        Quality Inn
# 148                                    Pono Kai Resort
# 149                                     No hotel found
# 152                                            Alerces
# 162                               Ballina Beach Resort
# 163                                  shakeel bhai room
# 164                                   Hotel Geetenjali
# 165                                       Yaseen hotel
# 175                                     No hotel found
# 199                                      Northwest Inn
# 215                                     No hotel found
# 216                                       فندق الدلفين
# 239  Bask Hotel Big Rock Landing, Trademark Collect...
# 249                                     No hotel found
# 265                          Khounxaisavanh Guesthouse
# 271                                     No hotel found
# 282                                        Kauai Palms
# 284                                        فندق الأمان
# 292                          Al Areen Hotel Apartments
# 299                 Hampton Inn Mobile-East Bay/Daphne
# 307                                         DoubleTree
# 310                                     Sapvilai Hotel
# 312                    Chesapeake Beach Resort and Spa
# 331                                     No hotel found
# 340                                        Royal Hotel
# 350                              Queen's Garden Resort
# 356                                          App Leyma
# 365                               Airborne Inn Lodging
# 368                                     No hotel found
# 377                                     No hotel found
# 379                                     No hotel found
# 383                                         Hotel Dale
# 390                                     No hotel found
# 422                                       Hotel Mexico
# 428                                     No hotel found
# 433                                  Pension pineapple
# 434                                       Glavas Hotel
# 442                                     No hotel found
# 475                           Inn At Mama's Fish House
# 480                                    Turtle Nest Inn
# 515                                          فندق مكثر
# 528                                        Peace Hotel
# 530                                      Nawaday Hotel
# 537                                          ရှုခင်းသာ
# 543                          Mariner Days Inn & Suites
# 567                                         Aqua Hotel
# 569                                     No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
#Gets rid of all cities where a hotel could not be found
hotel_df = hotel_df[hotel_df["Hotel Name"].str.contains("No hotel found") == False]
hotel_df
# Out:
#      City_ID                  City      Lat       Lng  Max Temp  Humidity  \
# 3          3     wailua homesteads  22.0669 -159.3780     77.43        75
# 32        32                 ha'il  27.5219   41.6907     44.62        57
# 42        42         fort mcmurray  56.7268 -111.3810     45.99        61
# 71        71               machico  32.7000  -16.7667     67.12        71
# 123      123               kyaukse  21.6000   96.1333     62.29        43
# 134      134         alice springs -23.7000  133.8833     72.95        21
# 146      146            greenville  35.6127  -77.3663     53.64        61
# 148      148                kapa'a  22.0752 -159.3190     78.78        74
# 152      152                  chui -33.6971  -53.4616     71.67        80
# 162      162               ballina -28.8667  153.5667     79.79        63
# 163      163               sharjah  25.3573   55.4033     75.18        73
# 164      164              kalundri  18.9833   73.1333     75.20        73
# 165      165                 aswan  24.0934   32.9070     51.10        43
# 199      199            slave lake  55.2834 -114.7690     44.58        57
# 216      216               zuwarah  32.9312   12.0820     55.65        60
# 239      239         morehead city  34.7229  -76.7260     53.65        74
# 265      265          luang namtha  20.9497  101.4011     54.82        77
# 282      282                 lihue  21.9789 -159.3672     78.04        73
# 284      284           tamanrasset  22.7850    5.5228     48.11        18
# 292      292               badiyah  22.4500   58.8000     69.10        76
# 299      299                daphne  30.6035  -87.9036     61.36        62
# 307      307                helena  46.5927 -112.0361     57.16        52
# 310      310  phayakkhaphum phisai  15.5163  103.1937     77.56        56
# 312      312      chesapeake beach  38.6862  -76.5347     52.75        73
# 340      340                 cooma -36.2333  149.1333     70.68        42
# 350      350            the bottom  17.6259  -63.2492     77.13        73
# 356      356             tazacorte  28.6290  -17.9293     71.15        35
# 365      365            fort bragg  35.1390  -79.0060     57.34        54
# 383      383              holdrege  40.4403  -99.3698     53.51        67
# 422      422        miguel ahumada  30.6167 -106.5167     73.38        21
# 433      433              skiathos  39.1623   23.4909     45.97        47
# 434      434             polygyros  40.3744   23.4383     40.60        44
# 475      475         haiku-pauwela  20.9219 -156.3051     78.82        70
# 480      480           bodden town  19.2833  -81.2500     75.20        68
# 515      515             ain sefra  32.7500   -0.5833     45.00        45
# 528      528                bentiu   9.2333   29.8333     74.68        16
# 530      530                loikaw  19.6742   97.2094     52.11        37
# 537      537             kyaikkami  16.0800   97.5675     75.88        77
# 543      543      kill devil hills  36.0307  -75.6760     44.98        73
# 567      567                  ovar  40.8586   -8.6251     59.02        69
#
#      Cloudiness  Wind Speed Country        Date  \
# 3            20        6.91      US  1706826840
# 32            0        9.22      SA  1706826846
# 42            0        5.75      CA  1706826641
# 71           20        5.75      PT  1706826854
# 123           1        4.23      MM  1706826865
# 134           1        4.61      AU  1706826867
# 146           0        3.44      US  1706826610
# 148          20        6.91      US  1706826870
# 152           0        8.39      UY  1706826871
# 162           8        4.85      AU  1706826873
# 163           0        5.75      AE  1706826873
# 164           0        4.09      IN  1706826874
# 165           0        4.61      EG  1706826874
# 199           0        5.75      CA  1706826880
# 216           5        5.14      LY  1706826884
# 239           0        8.05      US  1706826888
# 265           0        1.03      LA  1706826892
# 282          20        6.91      US  1706826737
# 284           0        4.61      DZ  1706826896
# 292          11        2.01      OM  1706826897
# 299           0        6.91      US  1706826899
# 307           0        0.00      US  1706826900
# 310           2        2.39      TH  1706826901
# 312          40        8.01      US  1706826901
# 340           0        3.91      AU  1706826908
# 350           1        7.87      BQ  1706826910
# 356           0        8.99      ES  1706826911
# 365           0        9.22      US  1706826913
# 383           0        5.75      US  1706826918
# 422           1        6.51      MX  1706826926
# 433           2        6.11      GR  1706826856
# 434           6        3.85      GR  1706826928
# 475          40        8.05      US  1706826937
# 480          20        9.22      KY  1706826938
# 515           1        3.74      DZ  1706826945
# 528           6        8.93      SS  1706826948
# 530           0        3.31      MM  1706826948
# 537           0        4.16      MM  1706826949
# 543           0        3.44      US  1706826950
# 567          14        4.43      PT  1706826955
#
#                                             Hotel Name
# 3                   Hilton Garden Inn Kauai Wailua Bay
# 32                                         فندق كلاسيك
# 42                              Nomad Hotel and Suites
# 71                                       Residence Inn
# 123                                   San Palace Hotel
# 134                               Aurora Alice Springs
# 146                                        Quality Inn
# 148                                    Pono Kai Resort
# 152                                            Alerces
# 162                               Ballina Beach Resort
# 163                                  shakeel bhai room
# 164                                   Hotel Geetenjali
# 165                                       Yaseen hotel
# 199                                      Northwest Inn
# 216                                       فندق الدلفين
# 239  Bask Hotel Big Rock Landing, Trademark Collect...
# 265                          Khounxaisavanh Guesthouse
# 282                                        Kauai Palms
# 284                                        فندق الأمان
# 292                          Al Areen Hotel Apartments
# 299                 Hampton Inn Mobile-East Bay/Daphne
# 307                                         DoubleTree
# 310                                     Sapvilai Hotel
# 312                    Chesapeake Beach Resort and Spa
# 340                                        Royal Hotel
# 350                              Queen's Garden Resort
# 356                                          App Leyma
# 365                               Airborne Inn Lodging
# 383                                         Hotel Dale
# 422                                       Hotel Mexico
# 433                                  Pension pineapple
# 434                                       Glavas Hotel
# 475                           Inn At Mama's Fish House
# 480                                    Turtle Nest Inn
# 515                                          فندق مكثر
# 528                                        Peace Hotel
# 530                                      Nawaday Hotel
# 537                                          ရှုခင်းသာ
# 543                          Mariner Days Inn & Suites
# 567                                         Aqua Hotel

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    color="City",
    alpha=.75,
    hover_cols=["Hotel Name", "Country"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
